# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Dataset Cleaning

# %%
ds_1=pd.read_csv('city_day.csv');

# %%
new_df = pd.concat([ds_1.iloc[:,0:2],ds_1.iloc[:,7:]],axis = 1)

new_df = new_df[new_df['City'] == 'Bengaluru']

# %%
new_df['Date'] = pd.to_datetime(new_df['Date'])

# %%
new_df['Year'] = new_df['Date'].dt.year

# %%
new_df = new_df.set_index(['Year'])

# %% [markdown]
# ## Making dataframes

# %%
ds_delhi_15=new_df.loc['2015'];
ds_delhi_16=new_df.loc['2016'];
ds_delhi_17=new_df.loc['2017'];
ds_delhi_18=new_df.loc['2018'];
ds_delhi_19=new_df.loc['2019'];
ds_delhi_20=new_df.loc['2020'];

# %%
ds_delhi_16
# Out:
#            City       Date    NH3    CO   SO2     O3  Benzene  Toluene  \
# Year
# 2016  Bengaluru 2016-01-01  14.68  0.69  7.44  55.96     0.91     0.78
# 2016  Bengaluru 2016-01-02  16.05  0.76  8.67  34.06     1.88     1.18
# 2016  Bengaluru 2016-01-03  16.37  0.96  9.10  47.62     2.36     1.14
# 2016  Bengaluru 2016-01-04  14.18  0.89  8.87  50.62     1.95     1.33
# 2016  Bengaluru 2016-01-05  16.97  0.85  9.41  36.94     1.92     1.26
# ...         ...        ...    ...   ...   ...    ...      ...      ...
# 2016  Bengaluru 2016-12-27  16.90  0.70  7.04  23.74     3.94     3.79
# 2016  Bengaluru 2016-12-28  17.07  0.20  4.32  17.27     3.16     2.63
# 2016  Bengaluru 2016-12-29  16.91  0.46  5.60    NaN      NaN      NaN
# 2016  Bengaluru 2016-12-30  17.46  0.57  5.58    NaN      NaN      NaN
# 2016  Bengaluru 2016-12-31  17.59  0.74  4.92  41.16     2.76     2.06
#
#       Xylene    AQI    AQI_Bucket
# Year
# 2016     NaN  101.0      Moderate
# 2016     NaN   92.0  Satisfactory
# 2016     NaN  108.0      Moderate
# 2016     NaN  109.0      Moderate
# 2016     NaN  114.0      Moderate
# ...      ...    ...           ...
# 2016     NaN   90.0  Satisfactory
# 2016     NaN   84.0  Satisfactory
# 2016     NaN   76.0  Satisfactory
# 2016     NaN   93.0  Satisfactory
# 2016     NaN  106.0      Moderate
#
# [366 rows x 11 columns]

# %% [markdown]
# # AQI DATAFRAMES

# %%
aqi_15 = ds_delhi_15.iloc[:,2].values;
aqi_16 = ds_delhi_16.iloc[:,2].values;
aqi_17 = ds_delhi_17.iloc[:,2].values;
aqi_18 = ds_delhi_18.iloc[:,2].values;
aqi_19 = ds_delhi_19.iloc[:,2].values;
aqi_20 = ds_delhi_20.iloc[:,2].values;

# %% [markdown]
# # Visualization Of The Data

# %%
aqi_level_15 = new_df.loc['2015']
aqi_level_16 = new_df.loc['2016']
aqi_level_17 = new_df.loc['2017']
aqi_level_18 = new_df.loc['2018']
aqi_level_19 = new_df.loc['2019']
aqi_level_20 = new_df.loc['2020']

# %%
aqi_level_17
# Out:
#            City       Date    NH3    CO   SO2     O3  Benzene  Toluene  \
# Year
# 2017  Bengaluru 2017-01-01    NaN  0.77  4.80  25.90     3.65     2.04
# 2017  Bengaluru 2017-01-02  17.62  0.68  4.93  29.95     2.35     2.36
# 2017  Bengaluru 2017-01-03  19.41  0.74  4.95  31.55     4.07     4.61
# 2017  Bengaluru 2017-01-04  24.85  0.76  4.58  39.09     4.02     3.48
# 2017  Bengaluru 2017-01-05  25.09  0.63  4.57  35.78     3.12     3.30
# ...         ...        ...    ...   ...   ...    ...      ...      ...
# 2017  Bengaluru 2017-12-27   9.77  0.91  3.40    NaN     0.00     0.97
# 2017  Bengaluru 2017-12-28  10.45  0.96  3.38  52.72     0.00     0.95
# 2017  Bengaluru 2017-12-29   9.60  1.13  3.60  17.18      NaN     1.20
# 2017  Bengaluru 2017-12-30   8.98  1.06  3.26  33.48      NaN     1.16
# 2017  Bengaluru 2017-12-31    NaN  1.02  2.95  32.36      NaN      NaN
#
#       Xylene    AQI    AQI_Bucket
# Year
# 2017     NaN   88.0  Satisfactory
# 2017     NaN   83.0  Satisfactory
# 2017     NaN   87.0  Satisfactory
# 2017     NaN   91.0  Satisfactory
# 2017     NaN   85.0  Satisfactory
# ...      ...    ...           ...
# 2017     NaN   99.0  Satisfactory
# 2017     NaN  109.0      Moderate
# 2017     NaN   85.0  Satisfactory
# 2017     NaN   77.0  Satisfactory
# 2017     NaN   72.0  Satisfactory
#
# [365 rows x 11 columns]

# %%
aqi_level_17.iloc[:,2],
# Out:
# (Year
#  2017      NaN
#  2017    17.62
#  2017    19.41
#  2017    24.85
#  2017    25.09
#          ...
#  2017     9.77
#  2017    10.45
#  2017     9.60
#  2017     8.98
#  2017      NaN
#  Name: NH3, Length: 365, dtype: float64,)

# %%
#2017
fig = go.Figure(go.Scatter(
    mode = "lines+markers",
    y = aqi_level_17.iloc[:,2],
    x = aqi_level_17.iloc[:,1]))
fig.update_xaxes(
        tickangle = 90,
        title_text = "Month",
        title_font = {"size": 20},
        title_standoff = 25)

fig.update_yaxes(
        title_text = "NH3",
        title_standoff = 25)
fig.update_layout(title_text="NH3 2017")

fig.show()
# Out:
# <div>                            <div id="05165ecf-8ed0-45eb-af1b-a3dd573eed9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05165ecf-8ed0-45eb-af1b-a3dd573eed9b")) {                    Plotly.newPlot(                        "05165ecf-8ed0-45eb-af1b-a3dd573eed9b",                        [{"mode":"lines+markers","x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-04T00:00:00","2017-03-05T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-11T00:00:00","2017-03-12T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-18T00:00:00","2017-03-19T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-25T00:00:00","2017-03-26T00:00:00","2017-03-27T00:00:00","2017-03-28T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-01T00:00:00","2017-04-02T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-08T00:00:00","2017-04-09T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-14T00:00:00","2017-04-15T00:00:00","2017-04-16T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-22T00:00:00","2017-04-23T00:00:00","2017-04-24T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-04-29T00:00:00","2017-04-30T00:00:00","2017-05-01T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-06T00:00:00","2017-05-07T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-11T00:00:00","2017-05-12T00:00:00","2017-05-13T00:00:00","2017-05-14T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-20T00:00:00","2017-05-21T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-25T00:00:00","2017-05-26T00:00:00","2017-05-27T00:00:00","2017-05-28T00:00:00","2017-05-29T00:00:00","2017-05-30T00:00:00","2017-05-31T00:00:00","2017-06-01T00:00:00","2017-06-02T00:00:00","2017-06-03T00:00:00","2017-06-04T00:00:00","2017-06-05T00:00:00","2017-06 ...

# %%
#2018
fig = go.Figure(go.Scatter(
    mode = "lines+markers",
    y = aqi_level_18.iloc[:,2],
    x = aqi_level_18.iloc[:,1]))
fig.update_xaxes(
        tickangle = 90,
        title_text = "Month",
        title_font = {"size": 20},
        title_standoff = 25)

fig.update_yaxes(
        title_text = "NH3",
        title_standoff = 25)
fig.update_layout(title_text="NH3 2018")

fig.show()
# Out:
# <div>                            <div id="327bdaab-da20-4677-a256-d115d9c922c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327bdaab-da20-4677-a256-d115d9c922c6")) {                    Plotly.newPlot(                        "327bdaab-da20-4677-a256-d115d9c922c6",                        [{"mode":"lines+markers","x":["2018-01-01T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-06T00:00:00","2018-01-07T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-13T00:00:00","2018-01-14T00:00:00","2018-01-15T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-20T00:00:00","2018-01-21T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-27T00:00:00","2018-01-28T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-03T00:00:00","2018-02-04T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-10T00:00:00","2018-02-11T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-17T00:00:00","2018-02-18T00:00:00","2018-02-19T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-24T00:00:00","2018-02-25T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-03T00:00:00","2018-03-04T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-10T00:00:00","2018-03-11T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-17T00:00:00","2018-03-18T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-24T00:00:00","2018-03-25T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-03-30T00:00:00","2018-03-31T00:00:00","2018-04-01T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-07T00:00:00","2018-04-08T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-14T00:00:00","2018-04-15T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-21T00:00:00","2018-04-22T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-28T00:00:00","2018-04-29T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-05T00:00:00","2018-05-06T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-12T00:00:00","2018-05-13T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-19T00:00:00","2018-05-20T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-26T00:00:00","2018-05-27T00:00:00","2018-05-28T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-02T00:00:00","2018-06-03T00:00:00","2018-06-04T00:00:00","2018-06-05T00:00:00","2018-06 ...

# %%
#2019
fig = go.Figure(go.Scatter(
    mode = "lines+markers",
    y = aqi_level_19.iloc[:,2],
    x = aqi_level_19.iloc[:,1]))
fig.update_xaxes(
        tickangle = 90,
        title_text = "Month",
        title_font = {"size": 20},
        title_standoff = 25)

fig.update_yaxes(
        title_text = "NH3",
        title_standoff = 25)
fig.update_layout(title_text="NH3 2019")

fig.show()
# Out:
# <div>                            <div id="15f49946-a9fd-4c98-a8fd-2f2b04abf18e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15f49946-a9fd-4c98-a8fd-2f2b04abf18e")) {                    Plotly.newPlot(                        "15f49946-a9fd-4c98-a8fd-2f2b04abf18e",                        [{"mode":"lines+markers","x":["2019-01-01T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-05T00:00:00","2019-01-06T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-12T00:00:00","2019-01-13T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-19T00:00:00","2019-01-20T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-26T00:00:00","2019-01-27T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-02T00:00:00","2019-02-03T00:00:00","2019-02-04T00:00:00","2019-02-05T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-09T00:00:00","2019-02-10T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-16T00:00:00","2019-02-17T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-23T00:00:00","2019-02-24T00:00:00","2019-02-25T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-02T00:00:00","2019-03-03T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-09T00:00:00","2019-03-10T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-16T00:00:00","2019-03-17T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-23T00:00:00","2019-03-24T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-03-30T00:00:00","2019-03-31T00:00:00","2019-04-01T00:00:00","2019-04-02T00:00:00","2019-04-03T00:00:00","2019-04-04T00:00:00","2019-04-05T00:00:00","2019-04-06T00:00:00","2019-04-07T00:00:00","2019-04-08T00:00:00","2019-04-09T00:00:00","2019-04-10T00:00:00","2019-04-11T00:00:00","2019-04-12T00:00:00","2019-04-13T00:00:00","2019-04-14T00:00:00","2019-04-15T00:00:00","2019-04-16T00:00:00","2019-04-17T00:00:00","2019-04-18T00:00:00","2019-04-19T00:00:00","2019-04-20T00:00:00","2019-04-21T00:00:00","2019-04-22T00:00:00","2019-04-23T00:00:00","2019-04-24T00:00:00","2019-04-25T00:00:00","2019-04-26T00:00:00","2019-04-27T00:00:00","2019-04-28T00:00:00","2019-04-29T00:00:00","2019-04-30T00:00:00","2019-05-01T00:00:00","2019-05-02T00:00:00","2019-05-03T00:00:00","2019-05-04T00:00:00","2019-05-05T00:00:00","2019-05-06T00:00:00","2019-05-07T00:00:00","2019-05-08T00:00:00","2019-05-09T00:00:00","2019-05-10T00:00:00","2019-05-11T00:00:00","2019-05-12T00:00:00","2019-05-13T00:00:00","2019-05-14T00:00:00","2019-05-15T00:00:00","2019-05-16T00:00:00","2019-05-17T00:00:00","2019-05-18T00:00:00","2019-05-19T00:00:00","2019-05-20T00:00:00","2019-05-21T00:00:00","2019-05-22T00:00:00","2019-05-23T00:00:00","2019-05-24T00:00:00","2019-05-25T00:00:00","2019-05-26T00:00:00","2019-05-27T00:00:00","2019-05-28T00:00:00","2019-05-29T00:00:00","2019-05-30T00:00:00","2019-05-31T00:00:00","2019-06-01T00:00:00","2019-06-02T00:00:00","2019-06-03T00:00:00","2019-06-04T00:00:00","2019-06-05T00:00:00","2019-06 ...

# %%
from plotly.subplots import make_subplots
fig = make_subplots(rows=2, cols=3,subplot_titles=("2015","2016", "2017", "2018","2019"))
fig.add_trace(
    go.Scatter(
    name ="2016",
    mode = "lines+markers",
    y = aqi_level_16.iloc[:,2],
    x = aqi_level_16.iloc[:,1]),
    row = 1 ,col =2)


fig.add_trace(go.Scatter(
    name ="2017",
    mode = "lines+markers",
    y = aqi_level_17.iloc[:,2],
    x = aqi_level_17.iloc[:,1]),
    row=1, col=3
)

    
    


fig.add_trace(go.Scatter(
    name ="2018",
    mode = "lines+markers",
    y = aqi_level_18.iloc[:,2],
    x = aqi_level_18.iloc[:,1]),
    row=2, col=1
)

fig.add_trace(go.Scatter(
    name ="2019",
    mode = "lines+markers",
    y = aqi_level_19.iloc[:,2],
    x = aqi_level_19.iloc[:,1]),
    row=2, col=2
)

fig.add_trace(go.Scatter(
    name ="2015",
    mode = "lines+markers",
    y = aqi_level_15.iloc[:,2],
    x = aqi_level_15.iloc[:,1]),
    row=1, col=1
)
fig.add_trace(go.Scatter(name="2020",
                         mode = "lines+markers", 
                         y = aqi_level_20.iloc[:,2],
                         x = aqi_level_20.iloc[:,1]),
                         row = 2,col = 3)
fig.update_layout(title_text="NH3 IN DIFFERENT YEARS", height=700)
fig.show()
# Out:
# <div>                            <div id="e356e19d-5d22-4825-a23d-77eaa5bcdae2" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e356e19d-5d22-4825-a23d-77eaa5bcdae2")) {                    Plotly.newPlot(                        "e356e19d-5d22-4825-a23d-77eaa5bcdae2",                        [{"mode":"lines+markers","name":"2016","x":["2016-01-01T00:00:00","2016-01-02T00:00:00","2016-01-03T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-09T00:00:00","2016-01-10T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-16T00:00:00","2016-01-17T00:00:00","2016-01-18T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-23T00:00:00","2016-01-24T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-01-30T00:00:00","2016-01-31T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00","2016-02-05T00:00:00","2016-02-06T00:00:00","2016-02-07T00:00:00","2016-02-08T00:00:00","2016-02-09T00:00:00","2016-02-10T00:00:00","2016-02-11T00:00:00","2016-02-12T00:00:00","2016-02-13T00:00:00","2016-02-14T00:00:00","2016-02-15T00:00:00","2016-02-16T00:00:00","2016-02-17T00:00:00","2016-02-18T00:00:00","2016-02-19T00:00:00","2016-02-20T00:00:00","2016-02-21T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-02-25T00:00:00","2016-02-26T00:00:00","2016-02-27T00:00:00","2016-02-28T00:00:00","2016-02-29T00:00:00","2016-03-01T00:00:00","2016-03-02T00:00:00","2016-03-03T00:00:00","2016-03-04T00:00:00","2016-03-05T00:00:00","2016-03-06T00:00:00","2016-03-07T00:00:00","2016-03-08T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-11T00:00:00","2016-03-12T00:00:00","2016-03-13T00:00:00","2016-03-14T00:00:00","2016-03-15T00:00:00","2016-03-16T00:00:00","2016-03-17T00:00:00","2016-03-18T00:00:00","2016-03-19T00:00:00","2016-03-20T00:00:00","2016-03-21T00:00:00","2016-03-22T00:00:00","2016-03-23T00:00:00","2016-03-24T00:00:00","2016-03-25T00:00:00","2016-03-26T00:00:00","2016-03-27T00:00:00","2016-03-28T00:00:00","2016-03-29T00:00:00","2016-03-30T00:00:00","2016-03-31T00:00:00","2016-04-01T00:00:00","2016-04-02T00:00:00","2016-04-03T00:00:00","2016-04-04T00:00:00","2016-04-05T00:00:00","2016-04-06T00:00:00","2016-04-07T00:00:00","2016-04-08T00:00:00","2016-04-09T00:00:00","2016-04-10T00:00:00","2016-04-11T00:00:00","2016-04-12T00:00:00","2016-04-13T00:00:00","2016-04-14T00:00:00","2016-04-15T00:00:00","2016-04-16T00:00:00","2016-04-17T00:00:00","2016-04-18T00:00:00","2016-04-19T00:00:00","2016-04-20T00:00:00","2016-04-21T00:00:00","2016-04-22T00:00:00","2016-04-23T00:00:00","2016-04-24T00:00:00","2016-04-25T00:00:00","2016-04-26T00:00:00","2016-04-27T00:00:00","2016-04-28T00:00:00","2016-04-29T00:00:00","2016-04-30T00:00:00","2016-05-01T00:00:00","2016-05-02T00:00:00","2016-05-03T00:00:00","2016-05-04T00:00:00","2016-05-05T00:00:00","2016-05-06T00:00:00","2016-05-07T00:00:00","2016-05-08T00:00:00","2016-05-09T00:00:00","2016-05-10T00:00:00","2016-05-11T00:00:00","2016-05-12T00:00:00","2016-05-13T00:00:00","2016-05-14T00:00:00","2016-05-15T00:00:00","2016-05-16T00:00:00","2016-05-17T00:00:00","2016-05-18T00:00:00","2016-05-19T00:00:00","2016-05-20T00:00:00","2016-05-21T00:00:00","2016-05-22T00:00:00","2016-05-23T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-05-27T00:00:00","2016-05-28T00:00:00","2016-05-29T00:00:00","2016-05-30T00:00:00","2016-05-31T00:00:00","2016-06-01T00:00:00","2016-06-02T00:00:00","2016-06-03T00:00:00","2016-06-04T00:0 ...

# %%
aqi_15.shape
# Out:
# (365,)

# %% [markdown]
# # Making arrays for last 5 days and present data

# %%
x_15=np.zeros((359,6));
point=0;
count=0;
for i in range(0,359,1):
    for j in range(0,6,1):
        x_15[i][j]= aqi_15[point];
        point += 1;
    count += 1;
    point = count;
    if (count == 359):
        break;

# %%
x_17=np.zeros((359,6));
point=0;
count=0;
for i in range(0,359,1):
    for j in range(0,6,1):
        x_17[i][j]= aqi_17[point];
        point += 1;
    count += 1;
    point = count;
    if (count == 359):
        break;

# %%
x_16=np.zeros((359,6));
point=0;
count=0;
for i in range(0,359,1):
    for j in range(0,6,1):
        x_16[i][j]= aqi_16[point];
        point += 1;
    count += 1;
    point = count;
    if (count == 359):
        break;

# %%
x_18=np.zeros((359,6));
point=0;
count=0;
for i in range(0,359,1):
    for j in range(0,6,1):
        x_18[i][j]= aqi_18[point];
        point += 1;
    count += 1;
    point = count;
    if (count == 359):
        break;

# %%
x_18
# Out:
# array([[  nan,   nan,   nan,   nan,   nan,   nan],
#        [  nan,   nan,   nan,   nan,   nan,   nan],
#        [  nan,   nan,   nan,   nan,   nan,   nan],
#        ...,
#        [16.35, 15.77, 16.55, 16.61, 16.37, 17.22],
#        [15.77, 16.55, 16.61, 16.37, 17.22, 17.7 ],
#        [16.55, 16.61, 16.37, 17.22, 17.7 , 16.  ]])

# %%
x_19=np.zeros((359,6));
point=0;
count=0;
for i in range(0,359,1):
    for j in range(0,6,1):
        x_19[i][j]= aqi_19[point];
        point += 1;
    count += 1;
    point = count;
    if (count == 362):
        break;

# %%
x_16.shape
# Out:
# (359, 6)

# %%
x_17.shape
# Out:
# (359, 6)

# %% [markdown]
# # Making a single dataframe of above arrays

# %% [markdown]
# Gathering All the data in one dataframe.

# %%
ds_5=np.concatenate((x_15,x_16,x_17,x_18,x_19),axis=0);

# %%
ds_5.shape
# Out:
# (1795, 6)

# %%
ds_5= pd.DataFrame(ds_5, columns = ['last 5th','last 4th','last 3rd','last 2nd','last 1st','present'])

# %%
ds_5
# Out:
#       last 5th  last 4th  last 3rd  last 2nd  last 1st  present
# 0        20.36     23.74      4.32      0.87     31.38    26.35
# 1        23.74      4.32      0.87     31.38     26.35    22.73
# 2         4.32      0.87     31.38     26.35     22.73    38.67
# 3         0.87     31.38     26.35     22.73     38.67    23.48
# 4        31.38     26.35     22.73     38.67     23.48    34.17
# ...        ...       ...       ...       ...       ...      ...
# 1790     14.47     13.50     13.96     13.71     14.05    14.55
# 1791     13.50     13.96     13.71     14.05     14.55    14.71
# 1792     13.96     13.71     14.05     14.55     14.71    13.37
# 1793     13.71     14.05     14.55     14.71     13.37    13.02
# 1794     14.05     14.55     14.71     13.37     13.02    12.91
#
# [1795 rows x 6 columns]

# %% [markdown]
# # Model Training

# %% [markdown]
# ### Step 1: Now we start the process of model training by making independent and dependent   variables

# %%
svr_X=ds_5.iloc[:,[0,1,2,3,4]].values;
svr_Y=ds_5.iloc[:,[-1]].values;

# %%
svr_X
# Out:
# array([[20.36, 23.74,  4.32,  0.87, 31.38],
#        [23.74,  4.32,  0.87, 31.38, 26.35],
#        [ 4.32,  0.87, 31.38, 26.35, 22.73],
#        ...,
#        [13.96, 13.71, 14.05, 14.55, 14.71],
#        [13.71, 14.05, 14.55, 14.71, 13.37],
#        [14.05, 14.55, 14.71, 13.37, 13.02]])

# %% [markdown]
# ### Step 2 :Removing the null values

# %%
from sklearn.impute import SimpleImputer;
ds_imputer=SimpleImputer(missing_values=np.nan,strategy='mean');
ds_imputer.fit(svr_X);
svr_X=ds_imputer.transform(svr_X);

# %%
# from sklearn.impute import SimpleImputer;
# ds_imputer=SimpleImputer(missing_values=np.nan,strategy='mean');
ds_imputer.fit(svr_Y);
svr_Y=ds_imputer.transform(svr_Y);

# %%
svr_X
# Out:
# array([[20.36, 23.74,  4.32,  0.87, 31.38],
#        [23.74,  4.32,  0.87, 31.38, 26.35],
#        [ 4.32,  0.87, 31.38, 26.35, 22.73],
#        ...,
#        [13.96, 13.71, 14.05, 14.55, 14.71],
#        [13.71, 14.05, 14.55, 14.71, 13.37],
#        [14.05, 14.55, 14.71, 13.37, 13.02]])

# %%
svr_Y
# Out:
# array([[26.35],
#        [22.73],
#        [38.67],
#        ...,
#        [13.37],
#        [13.02],
#        [12.91]])

# %% [markdown]
# ### Step 3: Test - Train - Split

# %%
from sklearn.model_selection import train_test_split;
svr_x_train,svr_x_test,svr_y_train,svr_y_test=train_test_split(svr_X,svr_Y,test_size=0.2,random_state=1);

# %% [markdown]
# ### Step 4 : Using Regression Model : Support Vector Regression

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(svr_x_train, svr_y_train);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
svr_y_pred=regressor.predict(svr_x_test); #prediction of testing data

# %%
svr_y_pred.shape
# Out:
# (359,)

# %%
svr_y_test.shape
# Out:
# (359, 1)

# %%
df_y =pd.DataFrame(np.concatenate((svr_y_pred.reshape(359,1),svr_y_test),axis =1),columns = ["Predicted","Actual"])

# %% [markdown]
# ## Comparision Of Predicted AQI and Actual AQI

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

trace1 = go.Scatter(
   
    y=df_y.iloc[:,-1],
    name="Actual",
    marker=dict(
        color='rgb(34,163,192)'
               )
)
trace2 = go.Scatter(
    y=df_y.iloc[:,0],
    
    name='Predicted',
    yaxis='y2'

)
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(trace1)
fig.add_trace(trace2,secondary_y=True)
fig['layout'].update(height = 600, width = 800, title = "SVR Comparision On Testing Data ",xaxis=dict(
      tickangle=-90
    ))
fig.show()
# Out:
# <div>                            <div id="45648f96-4dc0-4361-aa11-61abc2fcb0c6" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45648f96-4dc0-4361-aa11-61abc2fcb0c6")) {                    Plotly.newPlot(                        "45648f96-4dc0-4361-aa11-61abc2fcb0c6",                        [{"marker":{"color":"rgb(34,163,192)"},"name":"Actual","y":[13.37,37.44,21.13,15.25,17.82,27.58,23.27968105065666,25.71,18.8,6.42,29.6,26.22,26.54,14.07,23.27968105065666,25.6,107.53,15.05,27.39,40.36,30.38,12.55,49.59,13.56,24.82,26.88,14.09,22.0,18.69,26.24,45.07,15.83,27.73,40.67,17.03,23.27968105065666,15.44,27.54,10.23,39.7,14.47,13.92,34.63,19.55,24.47,33.06,21.02,40.67,29.89,23.27968105065666,15.54,23.27968105065666,20.9,40.82,50.58,37.08,11.35,7.02,23.86,12.28,24.15,16.
# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(svr_y_test, svr_y_pred)
# Out:
# 0.2805287448123155

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(svr_y_test,svr_y_pred)
# Out:
# 0.1918222462862462

# %% [markdown]
# ## Using Different Model For Comparision

# %% [markdown]
# ### 1.) XGBOOST Model

# %%
xg_X = np.concatenate((aqi_15.reshape(365,1),
                     aqi_16[[range(0,365)]].reshape(365,1),
                     aqi_17.reshape(365,1),
                     aqi_18.reshape(365,1),
                     aqi_19.reshape(365,1)),axis=1)
xg_Y = aqi_19.reshape(365,1);
# Out:
# <ipython-input-46-b3af51a578ec>:2: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
xg_X.shape
# Out:
# (365, 5)

# %%
xg_X[205,:]
# Out:
# array([10.06,  8.41, 27.22, 23.36, 11.97])

# %%
from sklearn.impute import SimpleImputer;
ds_imputer=SimpleImputer(missing_values=np.nan,strategy='mean');
ds_imputer.fit(xg_X);
xg_X=ds_imputer.transform(xg_X);
ds_imputer.fit(xg_Y);
xg_Y=ds_imputer.transform(xg_Y);

# %%
xg_x_train,xg_x_test,xg_y_train,xg_y_test=train_test_split(xg_X,xg_Y,test_size=0.2,random_state=1);

# %%
from xgboost import XGBRegressor;
xg_regressor=XGBRegressor();
xg_regressor.fit(svr_x_train, svr_y_train);#training ke liye 5 days ka data upr svr wale se

# %%
xg_pred=xg_regressor.predict(xg_X )#ismai jo data dalna hai vo 5 saal wala dalna hai
#orr ye 2020 ki values hai

# %%
svr_x_train
# Out:
# array([[23.31823603, 23.32119122, 23.3033396 , 23.30759549, 23.30387985],
#        [68.36      , 30.02      , 42.43      , 37.61      , 54.97      ],
#        [16.47      , 17.01      , 15.25      , 14.48      , 15.25      ],
#        ...,
#        [40.27      , 45.24      , 50.22      , 57.58      , 68.02      ],
#        [27.77      , 17.67      , 15.18      , 35.39      , 26.37      ],
#        [42.43      , 37.61      , 54.97      , 87.2       , 56.03      ]])

# %%
print(xg_x_test.shape)
# Out:
# (73, 5)

# %% [markdown]
# ### Error in XgBoost Model

# %%
xg_real_pred = xg_regressor.predict(svr_x_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(xg_real_pred,svr_y_test)
# Out:
# 0.20533735893865712

# %%
xg_pred.shape
# Out:
# (365,)

# %%
from sklearn.metrics import r2_score
r2_score(xg_real_pred, svr_y_test)
# Out:
# 0.22896601067183875

# %% [markdown]
# ### Visualization in XgBoost

# %%
df_xg =pd.DataFrame(np.concatenate((xg_pred[range(0,183)].reshape(183,1),
                                    aqi_20.reshape(183,1)),
                                   axis = 1 ),
                                columns = ["Predicted","Actual"])

# %%
df_xg
# Out:
#      Predicted  Actual
# 0    19.909822   13.01
# 1    20.159946   12.40
# 2    26.384420   12.87
# 3    25.287806   14.59
# 4    15.136696   15.68
# ..         ...     ...
# 178   9.601755    6.88
# 179  17.535437    6.58
# 180  13.039976    6.80
# 181  16.628599    6.82
# 182  19.051100    7.42
#
# [183 rows x 2 columns]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

trace1 = go.Scatter(
   
    y=df_xg.iloc[:,-1],
    name="Actual",
    marker=dict(
        color='rgb(34,163,192)'
               )
)
trace2 = go.Scatter(
    y=df_xg.iloc[:,0],
    
    name='Predicted',
    yaxis='y2'

)
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace
.801552772521973,14.878097534179688,17.11725616455078,20.380218505859375,21.060958862304688,20.311857223510742,20.056489944458008,15.511332511901855,15.182048797607422,13.627462387084961,16.368257522583008,13.738312721252441,13.323657989501953,14.706803321838379,15.956001281738281,12.999319076538086,14.397990226745605,14.259964942932129,19.862401962280273,19.88852310180664,14.694639205932617,13.537093162536621,14.583296775817871,15.312020301818848,17.722658157348633,7.130904674530029,19.61744499206543,12.116085052490234,18.81888198852539,21.31844711303711,18.83490753173828,14.225157737731934,15.019487380981445,16.017818450927734,14.617862701416016,16.6009578704834,16.512548446655273,14.941146850585938,12.721611976623535,18.42738151550293,18.47684097290039,15.14746379852295,17.267131805419922,24.951030731201172,14.528587341308594,15.202977180480957,18.55990982055664,21.770689010620117,19.438901901245117,17.659744262695312,17.819419860839844,19.042346954345703,21.05695915222168,16.827470779418945,20.003387451171875,21.622453689575195,20.63538360595703,18.965543746948242,15.41863727 ...

# %%
x=df_xg.iloc[85:,0]-df_xg.iloc[85:,-1]

# %%
x=df_xg.iloc[85:,0]-x

# %%
np.mean(x)
# Out:
# 8.824183673469387

# %%
a=np.mean(df_xg.iloc[85:,0])  #predicted

# %%
b=np.mean(df_xg.iloc[85:,-1]) #actual

# %%
t=(a-b)/a

# %%
t
# Out:
# 0.44302883817393635

# %% [markdown]
# ### 2.) Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor;
dtr_regressor=DecisionTreeRegressor(random_state=0);
dtr_regressor.fit(x_train,y_train);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-97a28e188814> in <module>
#       1 from sklearn.tree import DecisionTreeRegressor;
#       2 dtr_regressor=DecisionTreeRegressor(random_state=0);
# ----> 3 dtr_regressor.fit(x_train,y_train);
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ### Error In Decision Tree Model

# %%
dtr_pred=dtr_regressor.predict(x_test)
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,dtr_pred)

# %% [markdown]
# ### 3.) Random Forest Classification

# %%
from sklearn.ensemble import RandomForestRegressor;
rfr_regressor=RandomForestRegressor(n_estimators=10,random_state=0);
rfr_regressor.fit(x_train,y_train);

# %%
rfr_pred=rfr_regressor.predict(x_test)
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,rfr_pred)

# %%
aqi_16.shape

# %%
aqis=np.concatenate((aqi_15.reshape(365,1),aqi_16[[range(0,365)]].reshape(365,1),aqi_17.reshape(365,1),aqi_18.reshape(365,1),aqi_19.reshape(365,1)),axis=1)
aqis

# %%
xg_test=np.zeros((365,6));
for i in range(0,365,1):
    for j in range(0,5,1):
        xg_test[i][j]=aqis[i][j];

# %%
xg_pred_2020=xg_regressor.predict(aqis)

# %%
xg_pred

# %%
aqis_2021=np.concatenate((aqi_16[[range(0,365)]].reshape(365,1),aqi_17.reshape(365,1),aqi_18.reshape(365,1),aqi_19.reshape(365,1),xg_pred_2020.reshape(365,1)),axis=1)

# %%
xg_regressor.fit(x_train, np.ravel(y_train));

# %%
fig1=plt.figure()
plt.plot(xg_pred_2020[range(0,183)])
plt.plot(aqi_20)
plt.legend(['prediction 2020','true 2020'])

# %%
from sklearn.impute import SimpleImputer;
ds_imputer=SimpleImputer(missing_values=np.nan,strategy='mean');
ds_imputer.fit(aqis);
aqis=ds_imputer.transform(aqis);

# %%
plt.plot(xg_regressor.predict(aqis_2021))
# plt.plot(dtr_regressor.predict(aqis))
plt.plot(regressor.predict(aqis[:,[1,2,3,4]]))
plt.legend(['prediction xg','prediction dtr','prediction svr'])
